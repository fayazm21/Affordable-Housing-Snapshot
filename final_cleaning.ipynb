# %%
import pandas as pd
import numpy as np


df_rs = pd.read_csv("datasets/rent_smart.csv")
df_bv = pd.read_csv("cleaned_data/building_violations_cleaned.csv")
df_cv = pd.read_csv("cleaned_data/code_enforcement_cleaned.csv")
df_311 = pd.read_csv("cleaned_data/311_cleaned.csv")
df_parcel = pd.read_csv("datasets/parcel.csv")
# Out:
# C:\Users\SUEDA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3139: DtypeWarning: Columns (7,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\SUEDA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3139: DtypeWarning: Columns (15,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\SUEDA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3139: DtypeWarning: Columns (6,14,17,18,29,34) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
df_rs.head()
# Out:
#                   date          violation_type                  description  \
# 0  2022-10-27T00:00:00  Enforcement Violations  Improper storage trash: res
# 1  2022-10-27T00:00:00  Enforcement Violations  Improper storage trash: res
# 2  2022-10-27T00:00:00  Enforcement Violations  Improper storage trash: res
# 3  2022-10-27T00:00:00  Enforcement Violations  Improper storage trash: res
# 4  2022-10-27T00:00:00  Enforcement Violations  Improper storage trash: res
#
#                      address neighborhood  zip_code     parcel  \
# 0      26-30 Fleet St, 02113       Boston      2113  303176000
# 1  354-356 Hanover St, 02113       Boston      2113  302077000
# 2   16-18 Hanover Ave, 02109       Boston      2109  303116000
# 3    194 Salem St # 5, 02113       Boston      2113  302170000
# 4      213 Hanover St, 02113       Boston      2113  303288000
#
#                                 owner  year built  year remodeled  \
# ...

# %%
df_rs = df_rs[['violation_type', 'description', 'address', 'owner', 'latitude', 'longitude', 'date', 'year built']]
df_rs = df_rs.rename(columns={"year built": "year_built", 'date': 'violation_date'})
df_rs['address'] = df_rs['address'].apply(lambda x: x.upper())
df_rs
# Out:
#                 violation_type                       description  \
# 0       Enforcement Violations       Improper storage trash: res
# 1       Enforcement Violations       Improper storage trash: res
# 2       Enforcement Violations       Improper storage trash: res
# 3       Enforcement Violations       Improper storage trash: res
# 4       Enforcement Violations       Improper storage trash: res
# ...                        ...                               ...
# 309103     Sanitation Requests                Abandoned Vehicles
# 309104      Housing Complaints    Heat - Excessive, Insufficient
# 309105      Housing Complaints  Protection of Adjoining Property
# 309106      Housing Complaints  Protection of Adjoining Property
# 309107     Sanitation Requests                   Rodent Activity
#
#                              address                               owner  \
# 0              26-30 FLEET ST, 02113                    PIZZUTI DONATO F
# ...

# %%
df_bv = df_bv[['violation_type', 'description', 'address', 'owner_name', 'latitude', 'longitude', 'status_dttm', 'yr_built']]
df_bv = df_bv.rename(columns={"owner_name": "owner", 'yr_built': 'year_built', 'status_dttm': 'violation_date'})
df_bv
# Out:
#             violation_type               description             address  \
# 0      Building Violations  Failure to Obtain Permit    266 PRINCETON ST
# 1      Building Violations               Inspections    266 PRINCETON ST
# 2      Building Violations  Failure to Obtain Permit          85 COMO RD
# 3      Building Violations               Maintenance     53 TELEGRAPH ST
# 4      Building Violations               Maintenance     53 TELEGRAPH ST
# ...                    ...                       ...                 ...
# 24070  Building Violations               Inspections        20 BECKET ST
# 24071  Building Violations               Inspections        20 BECKET ST
# 24072  Building Violations               Inspections      225 CHELSEA ST
# 24073  Building Violations               Inspections  1670 WASHINGTON ST
# 24074  Building Violations               Inspections  1670 WASHINGTON ST
#
#                             owner  latitude  longitude       violation_date  \
# ...

# %%
df_cv = df_cv[['violation_type', 'description', 'address', 'owner_name', 'latitude', 'longitude', 'status_dttm', 'yr_built']]
df_cv = df_cv.rename(columns={"owner_name": "owner", 'yr_built': 'year_built', 'status_dttm': 'violation_date'})
df_cv
# Out:
#                    violation_type                     description  \
# 0          Enforcement Violations     Improper storage trash: res
# 1          Enforcement Violations     Improper storage trash: res
# 2          Enforcement Violations     Improper storage trash: res
# 3          Enforcement Violations     Improper storage trash: res
# 4          Enforcement Violations     Improper storage trash: res
# ...                           ...                             ...
# 33418      Enforcement Violations     Improper storage trash: res
# 33419      Enforcement Violations     Improper storage trash: res
# 33420      Enforcement Violations     Improper storage trash: res
# 33421          Housing Violations  Illegal dumping 1-5 cubic yd.:
# 33422  Civic Maintenance Requests   Occupying City prop wo permit
#
#                  address                                     owner   latitude  \
# 0      907 WASHINGTON ST            KENNEDY KEVIN & WHITE ANGELA M  42.279760
# ...

# %%
df_311 = df_311[['violation_type', 'case_title', 'address', 'owner_name', 'latitude', 'longitude', 'open_dt', 'yr_built']]
df_311 = df_311.rename(columns={"owner_name": "owner", "case_title": "description", 'yr_built': 'year_built', 'open_dt': 'violation_date'})
df_311
# Out:
#                 violation_type                          description  \
# 0           Housing Complaints       Heat - Excessive  Insufficient
# 1          Building Violations                    Illegal Occupancy
# 2          Building Violations                    Work w/out Permit
# 3          Building Violations              Maintenance - Homeowner
# 4          Building Violations                    Work w/out Permit
# ...                        ...                                  ...
# 357429  Enforcement Violations  Improper Storage of Trash (Barrels)
# 357430  Enforcement Violations  Improper Storage of Trash (Barrels)
# 357431  Enforcement Violations  Improper Storage of Trash (Barrels)
# 357432     Sanitation Requests                      Sticker Request
# 357433     Sanitation Requests           Request for Recycling Cart
#
#                    address                 owner  latitude  longitude  \
# 0            92 CHELSEA ST             KMF TRUST   42.3723   -71.0363
# ...

# %%
#creating  a df with all the violations
df_all = pd.concat([df_rs, df_bv, df_cv, df_311], axis=0)
df_all
# Out:
#                 violation_type                          description  \
# 0       Enforcement Violations          Improper storage trash: res
# 1       Enforcement Violations          Improper storage trash: res
# 2       Enforcement Violations          Improper storage trash: res
# 3       Enforcement Violations          Improper storage trash: res
# 4       Enforcement Violations          Improper storage trash: res
# ...                        ...                                  ...
# 357429  Enforcement Violations  Improper Storage of Trash (Barrels)
# 357430  Enforcement Violations  Improper Storage of Trash (Barrels)
# 357431  Enforcement Violations  Improper Storage of Trash (Barrels)
# 357432     Sanitation Requests                      Sticker Request
# 357433     Sanitation Requests           Request for Recycling Cart
#
#                           address                               owner  \
# 0           26-30 FLEET ST, 02113                    PIZZUTI DONATO F
# ...

# %%
#classes for violations
low = ['Abandoned Vehicles','Failure clean sidewalk com', 'Failure clear sidewalk - snow', 'Basic Principles', 'Failure clear sidewalk - snow:', 'Failure of Delivery Standards', 'Abandoned Bicycle',  'Abandoned Building', 'Access to Public Way', 
 'Adjacent to Excavations', 'Building', 'Graffiti on building- 1', 'Graffiti on building- 2', 'Contractor Complaints', 'No Number On A Building', 'Graffiti on building- 1', 'Graffiti on building- 2',  'Improper storage trash: com', 'Improper storage trash: res',
 'Clothes Dryer Exhaust', 'Owners Installation/Maintenance Responsibility - All Owner-installed optional equipment',
 'Owners Responsibility to Maintain Structural Elements - Structural elements  shall be maintained free from holes, cracks, loose plaster, or other defects.', 'Shopping Cart - 1', 'Shopping Cart - 2', 'Short Term Rental', 'Removal snow non-res property', 'Removal snow private prop',
 'Removal snow private property', 'Rental Unit Delivery Conditions', 'Required Inspections', 'Required Plumbing Fixtures', 'Requirements.', 'Posting signs wo authority', 'General - Stairways', 'Empty Litter Basket', 'Litter Basket Maintenance', 
 'Contractors Complaint' 'Corridor Continuity', 'Covers & Canopies', 'Non-Emergency Auto Repair', 'Foyer & Lobbies', 'Address Identification', 'Large building recycling - 2',
 'Large building recycling- 1', 'Right of Entry', 'Roadway Repair', 'Street Numbers' 'Student Overcrowding', 'Unlawful Continuance', 'Unregistered motor vehicles- 2',
 'Unregistered motor vehicles-1', 'Failure clean sidewalk com', 'Failure clear sidewalk - snow:',  'Removal snow private prop', 'Removal snow private property',  'Graffiti on building- 1', 'Graffiti on building- 2', 
 'Failure clear sidewalk - snow', 'No Number On A Building', 'Improper storage trash: res', 'Maint. of Areas Free from Garbage & Rubbish - Dwelling that contains 3 units or less, occ shall be responsible for maintaining in a clean & sanitary condition, free of garbage & filth the stairways leading/landing adjacent to his unit if.',
 'Maint. of Areas Free from Garbage & Rubbish(Common Areas) - In any dwelling, the owner shall be responsible for maintaining in a clean and sanitary condition free of garbage, rubbish, filth all common areas.',
 'Maint. of Areas Free from Garbage & Rubbish(Land) - The owner of any parcel of land, vacant or otherwise, shall be responsible for maintaining such parcel of land in a clean and sanitary condition.',
 'Maint. of Areas Free from Garbage & Rubbish(Units) - Occupantof any dwelling unit shall be responsible for maintaining in a clean and sanitary condition and free of garbage, rubbish, other filth or causes of sickness that part of the dwelling which he excusively occupies or controls.',
 'Maintenance of Exterior', 'Maintenance-Sprinkler', 'Collection of Garbage & Rubbish - Owner of any dwelling that contains 3 or more dwelling units, rooming house, and the occ. of any other unit shall be responsible for the final collection or ultimate disposal or incineration of garbage and rubbish by means of regular municipal Collection Sys.',
 'Occupants Installation/Maintenance Responsibility - Occupant shall exercise reasonable care and proper use of all equipment.',
 'Occupants Installation/Maintenance Responsibility - Occupant shall install in accordance with all acceptable codes plumbing, gas fitting and electrical; and maintain',
 'Occupants Responsibility Respecting Structural Elements - Occupant shall exercise reasonable care in the use of all structural elements of the dwelling.',
 'On-Site Presence of Supervisor', 'Openings', 'Openings to be closed',  'Overfilling of barrel/dumpster',
 'Openings to be closed.', 'Working Without a Permit', 'Workmanship', 'illegal parking prop owner 2', 'Decorative Material', 'Design', 'Design/construction of vent.',
 'Deteriorating Agents', 'Disconnecting Means', 'Attachment',  'Automatic Sprinkler System',
 'Basements', 'Bathroom Lighting & Electrical outlets - Owner shall provide in each room containing  a toilet, bathtub, or shower, 1 electric light fixture',
 'Boston Zoning Code', 'Boxes Where Required', 'Boxes, Where Required', 'Dumpster & Loading Noise Disturbances', 'Generic Noise Disturbance', 
 'Branch Circuit Extensions', 'Fences' , 'Swimming Pools', 'Size and Rating' ,
 'Space About Electrical Service', 'Unshoveled Sidewalk', 'Improper Storage of Trash (Barrels)', 'Loud Parties/Music/People', 
 'Missed Trash: District 1A', 'Municipal Parking Lot Complaints',  'Automotive Noise Disturbance', 'Big Buildings Online Request',
 'Big Buildings Recycling (INTERNAL)', 'CE Collection',
 'Building Identification - Owner shall to every building a # representing the address.',
 'Buildings hereafter altered', 'Circuit Impedance', 'Clear Width', 'Clearance',
  ]



medium = ['Failed Multiple Rental Insp', 'Excessive Use of Ext. Cords', 'Fail to post management comp', 'Failed to comply w permit term' 'Failure To Register', 'Failure to Obtain Inspection', 'Failure to Obtain Permit',
 'Failure to Secure Permit', 'Failure to call Inspections', 'Failure to call for req Insp.', 'Failure to secure a Re-Inspect',
 'Failure to secure permit', 'Fire Alarm and Detection' , 'Heat - Excessive, Insufficient', 'Exceeding Terms of Permit', 'Certificate of Occupancy', 'Building Inspection Request',  'Building or Use of Premise req','Illegal dumping w a vehicle', 
 'Certificate of Inspection', 'Construction Documents', 'No use of premises permit:', 'Illegal dumping 1-5 cubic yd.:', 'Illegal dumping 5+ cubic yd', 
 'Illegal dumping < 1 cubic yd', 'Illegal dumping park',  'Notice of Violation', 'Number of Exits or Exit Access',
 'Occupying City prop wo permit', 'Occupying W/Out A Valid CO/CI', 'Operational Constraints', 'Exhaust Installation', 'Exhaust Openings', 'Exits Maintained', 'Overcrowding', 'Overfilling of barrel/dumpster'
 'Locks and Latches', 'Maint a dumpster wopermit', 'Maintenance',
 'Maintenance - Homeowner', 'Maintenance Complaint - Residential', 'Overflowing or Un-kept Dumpster', 'Footing & Foundation Insp.',  'Inspection of exterior walls.', 'Inspections', 'Installation; 2015',
 'Int. Exit  Stairways & Ramps',  'Rooftop & Mechanical Disturbances', 'Sewage/Septic Back-Up',  'Owners Installation/Maintenance Responsibility - All Owner-installed optional equipment',
 'Owners Responsibility to Maintain Structural Elements - Structural elements  shall be maintained free from holes, cracks, loose plaster, or other defects.',
 'Periodic Inspections', 'Permits', 'Permits to perform gas fitting',  'Projections', 'Protection of Adj. Property',
 'Protection of Adjoining Property', 'Protection of Pedestrians', 
 'Referenced Codes & Standards', 'Reg. Access to Roof Areas',
 'Reg. of Construction Hour', 'Reg. of Construction Hours', 'Site Cleanliness license  VIO' 'Site Cleanliness license  WAR',
 'Smoke Detectors & Carbon Monoxide Alarms - Owner shall provide, install and maintain in operable condition smoke detectors and carbon monoxide alarms',  'Support Wires',  'Specialized codes', 'Squalid Living Conditions', 'Stop Work Order'
 'Testing & Certification', 'Transporting refuse without pe', 'Trash illegally dump container',
 'Trash on Vacant Lot',  'Unsatisfactory Utilities - Electrical, Plumbing', 'Uses not Permitted',
 'Utility Call-In', 'Utility Casting Repair', 'Validity of Permit',
 'Window Wells', 'Work w/out Permit', 'Work without permit', 'Working Beyond Hours', 'Working Space', 'Zoning',
 'illegal parking prop owner 1' 'illegal parking prop owner 2', 'Illegal dumping 1-5 cubic yd.:', 'Illegal dumping 1-5 cuyd.',
 'Illegal dumping 5 cubic yd.', 'Illegal dumping 5+ cubic yd', 'Illegal Dumping', 'Illegal Posting of Signs',
 'Illegal dumping < 1 cubic yd', 'Illegal dumping w a vehicle', 'Sign: COB Zoning Article 11-1', 'Trash illegally dump container','illegal parking prop owner 1', 'Failure to Obtain Inspection', 'Failure to secure a Re-Inspect',  'Board Up Property (Ch 139-3A)', 'Fail to post management comp',
 'Posting signs wo authority',  'Large building recycling- 1',  'Maint a dumpster wopermit', 'Maintain vacant/foreclose prop', 'Occupying City prop wo permit', 'Common area branch circuits', 'Compliance with Permit',
 'Failed to comply w PRMT terms', 'Temporary Occupancy',
 'Temporary Wiring - No wiring shall lie under rug or fl covering;nor extend through a doorway.',
 'Temporary Wiring Methods', 'Testing & Certification',
 'Failed to comply w permit term', 'Failure To Register',
 'Failure to Comply w Bldg Code', 'Failure to Comply w. Code',
 'Failure to comply w permits', 'Failure to remove or make',
 'False Statements', 'Metering of Electricity, Gas and Water - If Owner is not required to pay electrical and gas.  The owner must install piping and meters that serve on that unit.',
 'Metering of Electricity, Gas and Water - If required by owner, Electrical or Gas maybe be metered through meters serving multiple units.',
 'Metering of Electricity, Gas and Water - Owner shall provide Electricity and Gas, or letting agreement that payment is by the occupant',
 'Metering of Electricity, Gas and Water -Occupant Shall have access to any water submetering to ensure it is functioning properly.',  'Property Maintenance', 'Protection of conductors',
 'Protective Railings and Walls - Balusters no more than 6 in. apart between required gaurdrails and open handrails.',
 'Protective Railings and Walls - Safe handrail for every stairway',
 'Protective Railings and Walls - Wall or guardrail on open side of all stairways no less than 30 in. in height',  'Minimum square footage (Sleeping) -Room for sleeping, at least 70 sq. ft. of fl space; if more than 1 occ. at least 50 sq. ft.',
 'Modification fire protection', 'Mounting & Cooling Equipment',
 'Mounting Elec. Equipment',
 'Natural Lighting-Habitable Room other that kitchen - Window that admits light from outdoors equal in area to no less that 8% of entire fl area in that room.',
 'No GFCI in Kithen', 'Other Laws', 'Overcurrent Protection',
 'Pull & Junction Box', 'Referenced Codes', 'Remove/Making Safe Structure',
 'Repair', 'Retaining Wall', 'Revocation of Cert. of Occ.',
 'Revocation of Certificate',
 'No Switch for Ventiliation - Requires switch for shut-off or volume reduction.',
 'Non-Absorbent Surfaces - A non-absorbent floor surface of a bathroom, kitchen and pantry.',
 'Non-Absorbent Surfaces - A non-absorbent wall surface of a bathroom up to 4 ft; shower compartment no less than 6 ft.',
 'Not Located in Bathrooms', 'Number of Services', 'Occupancy', 'Mechanical Ventilation capable of exhausting air at the following rate: Habitable room other than bath, toilet or shower room- 2 air exchanges per hour. Bath, toilet or shower- 5 air exchanges per hour.',
 'Metal Chimeys', 'Meter Tapping', '2011 Mass Elec. Code Rule 1',
 'Amperage - Electric service shall supply sufficient amperage to meet the reasonable needs of the occupants.',
 'Any structure for swimming', 'Application for Permit',
 'Application for permit', 'Approval of Documents', 'Approval required',
 'Asbestos Material - Owner shall maintain all asbestos material in good repair, free from any defects.', 'Spaces About Elect. Equip.', 'Spaces about Elect. Equip.',
 'Spaces about electrical equip', 'Stop Work Order',
 'Storage and Placement-material',
 'Storage of Garbage & Rubbish - Garbage or mixed garbage and rubbish shall be stored in watertight receptacles with tight-fitting covers.  Said receptacles and covers shall be of metal or other durable rodent-proof material ',
 'Storage of Garbage & Rubbish - Plastic bags shall be used to store garbage or mixed garbage or rubbish only, if used as a liner in watertight receptacles with tight-fitting covers as required in Regulation 410.600A',
 'Storage of Garbage & Rubbish-Owner of dwelling w/ 3 units or more/rooming house shall provide as many receptacles needed for garbage as are sufficient.  before final collection and be located convenient to the occ that no objectionable odors enter any dwelling',
 'Street Numbers', 'Student Overcrowding',  'Services During Construction',
 'Shared Facilities - Sinks, Toilets, Tubs, showers shared by more than 1 unit or 1 rooming unit shall be cleaned and sanitized once every 24 hrs by owner.',
 'Side Yard Requirements',
 'Sinks, Toilets, Tubs, Showers (Fixtures) - Shall have a smooth and impervious surface free from defects',
 'Sinks, Toilets, Tubs, Showers - Owner shall provide a toilet, a wash basin, bathtub or shower in another room which is not used for living, sleeping, cooking or eating; room must be fitted with a door capable of being closed',
 'Light fixtures other that in Habitable rooms or kitchen - Owner shall provide electric light switches and fixtures in good working condition.',
 'Light fixtures other that in Habitable rooms or kitchen - Owner shall provide working incandescent light bulbs or fluorescent tubes in all required light fixtures in all common areas.',
 'Light in Passageways, Hallways, Stairways - Less than 3 units, Owner is responsible unless letting agreement is provided stating that dwelling unit is responsible for adjacent common area lighting;notify other occupants.',
 'Light in Passageways, Hallways, Stairways - Owner shall provide light 24 hrs per day',
 'Live loads(roof)', 'Locks and Latches', 'Locks and Latches (Gate)',  'Owners Installation/Maintenance Responsibility - All facilities and equipment which are required by owner including but not limited to water, gas, electrical and heating, shall be installed in accordance with all accepted codes.',
 'POST OWNER NAME', 'Permit Secured by Owner', 'Illegal Temporary Wiring', 'Illegally occupied prior to CO',
 'Illumination', 'Imbedded posts&poles', 'Improper Electrical Repair',
 'Inspection Upon Request', 'Installation Instructions',
 'Installation fo Screens - Owner shall provide and install screens so that they shall be in place during the period between April 1 to October 30th, both inclusive, in each year.',
 'Integrity of', 'Integrity of Elec. Equip.', 'Integrity of elec. equipment', 'Testing an Identification', 'Testing&Maintenance Sprinklers',
 'Unused Openings', 'Unused openings',
 'Use & Occupancy', 'Dwelling Units & Sleeping', 'Dwelling unit branch circuits.',
 'Effect of Non-Conforming Use' , 'Temperature Requirements - Min. 68F between 7:00 AM and 11:00 PM; atleast 64F between 11:01 PM and 6:59 AM; Temp shall at no time exceed 78F during heating season.',
 'Use of Lead Paint Prohibited - No paint that contains lead shall be used.',
 'Use of Premises', 'Uses Not Permitted', 'Uses not permitted',
 'Violation penalties',  'Construction Safeguards', 'Contractors Complaint', 'Corridor Continuity',
 'Curtailment Prohibited - No Owner or occ. shall cause any service, equipment, utility which is required to be made available by 105 CMR410.000 to be removed from or shut off from any occupied dwelling, unless for temp. repairs or alterations and reasonable notice of curtailment of service is given.',
 'Interior Enviroment', 'Mass State Plumbing Code', 'Mass. State Electrical Code', 'Final Inspection', 'Hearing Notice', 
 'Landings', 'Landings Required', 'Submittal Documents', 'Supports', 'Parking on Front/Back Yards (Illegal Parking)', 
 'Table A Use Item 34A', 'Poor Conditions of Property', 'Recycling Cart Inquiry',  'Ground Maintenance: Boston Common  ',
 'Ground Maintenance: Fallon Field  Fallon Field',
 'Ground Maintenance: Flaherty Playground  ',
 'Ground Maintenance: Foster St. Play Area  ',
 'Ground Maintenance: Franklin Park  ', 'Poor Conditions of Property' 'Recycling Cart Inquiry',
 'Recycling Cart Return', 'Request for Recycling Cart', 'Sticker Request',  'Damaged Cart - New Request',
 'Ground Maintenance: Pagel Playground  ',
 'Ground Maintenance: Symphony Community Park  ', 'Illegal Auto Body Shop',
 'Maximum Height from Floor', 'Means of Attachment', 'Site Cleanliness license  VIO', 'Site Cleanliness license  WAR',

 ]



high = ['Extermination of Insects, Rodents and Skunks - Extermination shall be accomplished by eliminating the harborage places of insects and rodents.  All use of pesticides shall be in accordance with applicable laws and regulations of the Department of Food and Agricultures Pesticide Board.',
 'Extermination of Insects, Rodents and Skunks - Occupant of a dwelling containing one dwelling unit shall maintain it and its premises free from all rodents, cockroaches and insect infestation and shall be responsible for exterminating them ',
 'Extermination of Insects, Rodents and Skunks - The owner of a dwelling containing two or more dwelling units shall maintain it and its premises free from all rodents, cockroaches and insect infestation and shall be responsible for exterminating them',
 'Extermination of Insects, Rodents and Skunks - The owner of a rooming house shall maintain it and its premises free from all rodent, cockroaches, and insect infestation and shall be responsible for exterminating them ',  'Fire Blocking Required' 'Fire Extinguishers', 'Fire Protection Systems',
 'Fire Separation', 'Fire and Smoke Protection', 'Accessible Means of Egress', 'Bed Bugs', 'Chronic Dampness/Mold',  'Breathe Easy', 'Carbon Monoxide',  'No Utilities Residential - Electricity', 'Illegal Rooming House', 'Illegal Use', 'Illegal Vending', 
 'Illegal dumping: Haz Waste', 'Construction Safe Guards','No Utilities Residential - Gas' 'No Utilities Residential - Water', 'No Utilities Residential - Gas', 'No Utilities Residential - Water', 'Maintenance of Means of Egress', 'Means of Egress', 'Mechanical',
 'Mechanical Execution of Work', 'Mice Infestation - Residential',
 'Minimum Number of Exits', 'Minimum Requirements', 'Egress', 'Means of Egress - As many means of exit as will allow for safe passage.', 'Egress', 'Egress Maintenance',
 'Means of Egress Illumination', 'Means of egress doors',
 'Modification fire protection', 'Mosquitoes (West Nile)',
 'Municipal Bylaws or Ordinances', 'National Fuel Gas Code', 'News Boxes', 'Catchbasin', 'Cross Metering - Sub-Metering', 'Dangerous Structures/Premises' , 'Unsafe Conditions', 'Unsafe Dangerous Conditions', 'Unsafe Maintanence',
 'Unsafe Structure', 'Unsafe Structures', 'Unsafe and Dangerous', 'Unsatisfactory Living Conditions', 'Egress Doors', 'Egress through intervening spaces',
 'Egress thru Intervening Spaces', 'Elec work w/o per', 'Electrical',  'Guarding of Live parts', 'Handrails', 'Electrical Connections', 'Electrical Work w/out a Permit',
 'Emergency Disconnects', 'Emergency Escape', 'Emergency Escape & Rescue',
 'Emergency Openings', 'Emergency escape and rescue', 'Deteriorating Agents' 'Dwelling Units & Sleeping', 'Lead', 'Overgrown Weeds On Property', 'Groups R-1, R-2, R-3 & R-4', 'AFCI',
 'Acts 1956 as Amended', 'I.S.S.U', 'Illegal Occupancy', 'Rodent Activity', 'Rat Bite','Pest Infestation - Residential', 'Pigeon Infestation',
 'Placement of Backfill', 'Plumbing', 'Poor Ventilation', 'Suspension or Revocation', 'Termination', 'Two exits or exit access doorways.',  'Unsafe Building & Structures', 'disposal med waste', 'Failed Multiple Rental Insp', 'Overgrown Weeds On Property',
 'Door Locks-Owner, install & maintain - Every door of dwelling/rooming unit able to be secured against unlawful entry',
 'Door Locks-Owner, install & maintain - Every dwelling unit able to be secured against unlawful entry.',
 'Door Locks-Owner, install & maintain - Locking devices shall compy with rqmts. of 780 CMR 1017.4.1 to avoid entrapment in the building.',
 'Door Locks-Owner, install & maintain - Main entry door of dwelling w/ 4+ units, close and lock automatically, elec. Operated striker and ass. equip.',
 'Door Operations', 'Door operations-Egress doors', 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to comply with any provisions of 105CMR 410.600, 410.601, 410.602 which may provide a food source or harborage for rodents, insects or other pests or otherwise contribute to accidents or to the creation or spread of disease.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to install electrical, plumbing, heating and gasburning facilities in accordance with accepted standards or failure to maintain such facilities as are required by 105CMR 410.351 & 410.352.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to provide a smoke detector or carbon monoxide alarm required by 105 CMR 410.482.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to provide a supply of water sufficient in quantity, pressure and temperature, both hot and cold, to meet the ordinary needs of the occupant in accordance with 105 CMR 410.180 and 410.190 for a period of 24 hours or longer.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to provide a toilet and maintain a sewage disposal system in operable condition as required by 105 CMR 410.150(A)(1) and 410.300.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to provide adequate exits, or the obstruction of any exit, passageway or common area caused by any object, including garbage or trash, which prevents egress in case of an emergency 105 CMR 410.450, 410.451 and 410.452.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to provide heat as required by 105 CMR 410.201 or improper venting or use of a space heater or water heater as prohibited by 105 CMR 410.200(B) and 410.202',
 'Conditions Deemed to Endanger or Impair Health or Safety - Failure to provide the electrical facilities required by 105 CMR 410.250(B), 410.251(A), 410.253 and the lighting in common area required by 105 CMR 410.254.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Roof, foundation, or other structural defects that may expose the occupant or anyone else to fire, burns, shock, accident or other dangers or impairment to health or safety.',
 'Conditions Deemed to Endanger or Impair Health or Safety - Shutoff and/or failure to restore electricity, gas or water.', 'Fire  & Smoke Alarm Systems', 'Fire Alarm & Detection', 
 'Through Penedtrations', 'Type NM Cable', 'Unfit for Human Occupancy', 'Hazrdous Means of Egress', '2 Means of Egress Required', 
 'Ungrounded Conducters', 'Unlawful Acts', 'Unsafe & Dangerous',
 'Unsafe Maintenance', 'Carbon Monoxide Detectors',  'Plumbing Connections - Kitchen sink, wash basin and shower or toilet shall be connected to hot and cold water lines, and sanitary drainage system.',
 'Plumbing Connections - Toilet shall be connected to water distribution system and  sanitary drainage system.',
 'Carbon Monoxide Protection', 'Carbon monoxide alarms',  'Fire Alarm Ent. Response', 'Fire Alarm Systems', 'Fire Blocking Required',
 'Fire Escape Affidavit', 'Fire Extinguishers', 'Fire Separation Assemblies',
 'Fire Stop System', 'Fire Wall/Fire Resistance', 'Fire-resistance rating', 'Abandoned Cable', 'Acoustical Ceiling Systems',  'Pool barrier', 'Portable Fire Extinguishers',
 'Portable fire extinguishers', 'Automatic Smoke Detection',
 'Potable Water - Owner shall supply potable water sufficient in quantity and pressure; may not shut off or refuse service.',
 'Principle #18', 'Prohibited Locations', 'Proper Maintenance',  'Heating Facilities - Portable space heaters, any similar heaters having a barometric fed fuel control, as well as the type of heating appliance adapted for burning kerosene, shall not be used and shall not meet the requirements.',
 'Heating Facilities Required - Owner shall provide & maintain in good operating condition the facilities for heating every habitable room and every room containing a toilet, shower or bathtub.',
 'Horozontal assemblies;Fire', 'Auxiliary Emergency Lightin Systems and Exit Signs - Owner of dwelling w/ 10+ units shall provide an auxiliary emergency lighting system.', 'Egress Obstruction - No person shall obstruct any exit or passageway.',
 'Hot Water - Facilities for providing a min. temperature of hot water at 110F , max. temperature 130F', 'Drainage System - Owner shall provide a sanitary drainage system connected to the public sewerage system.',
 'Weathertight Doors',
 'Weathertight Structual Elements - Exterior/interior, walls, floors, ceilings, cracks and spaces are caulked and filled to prevent infiltration of exterior air or moisture.',
 'Weathertight Windows',
 'Window Locks-Owner, install & maintain - ALL openable ext. window shall be capable of being secured.',
 'Wiring Integrity', 'Wiring Intensity', 'Wiring Methods', 
 'Room Ventilation - Window or door to exterior opened to a min of 4% of fl area of that habitable room, or room with toilet, bathtub or shower.',
 'Room Ventilation- window or door to exterior opened to a min of 4% of floor area of that habitable room, or room containing a toilet, bathtub or shower.',
 'Rooves and drainage', 
 'Safe Conditions - Owner shall maintain all means of egress safe and in operable condition.',
 'Screens for Doors - Owner shall provide screens for all doorways opening directly to the outside from any dwelling unit or rooming unit; shall be tight fitting; equipped with self-closing device except where screen is designed to slide to the side.',
 'Screens for Windows - Owner shall provide screens for all windows on the first 4 floors opening directly to the outside; shall be tight fitting; shall cover opening part of window designed to open',
 'Secured in Place', 'Securing & Supporting', 'Securing and Supporting', 'Dead Load' , 'Door Locks',
 'Securing and supporting', 'Service Size & Rating', 'Ceiling Height - Room not considered habitable if more than 3/4 of floor to Ceiling height is less than 7 ft.',
 'Elec. Equip. & Connections',
 'Electric outlets-Habitable Room - 2 separate wall-type outlets; or 1 outlet and 1 electric light fixture.',
 'Electrical Work w/out Permit', 'Electrical equipment integrity',
 'Electrical outlets/Light Fixture-kitchen - 1  electric light fixture; and 2 wall-type outlets located in convenient locations.',
 'Emergency Exit', 'Emergency Power Illumination',  'Flex cords/cables not permited', 'Floor Surface', 'Gates',
 'Grade Level - More that 1/2 of floor to ceiling height is below average grade of adjoining ground.',
 'Groundings', 'Guarding of Live Ports', 'Guarding of live parts', 'Guards',
 'Guards Where Required', 'Hand Rails', 'Handrails/safety',  'Smoke Detectors & Carbon Monoxide Alarms - Board of Health shall not impose additional requirements if local fire dpmt found dwelling to be adequately equipped.',
 'Smoke Detectors & Carbon Monoxide Alarms - Board of Health shall notify chief of local fire dpmt of any violations under 105 CMR 410.482',
 'Smoke alarm locations', 'Construction Debris',
 'Hazard Materials',  'Kitchen Facilities - Owner shall provide suitable space to store, prepare and serve foods in a sanitary manner; a kitchen sink, a stove and oven, proper facilities for the use of a refrigerator; facilities shall have smooth and impervious surfaces and be free from defects.',
 'Examination,identify,install', 'Exit Access', 'Exit Continuity', 'Smoke Alarms', 'Smoke Detectors',
 'Exit Enclosures', 'Exit Passageways', 'Exit Signs' ,'Exit passageways', 'Heat - Excessive  Insufficient',
 'Exits', 'Expiration', 'Exposed work',  'Maintenance/Fire Protection', 'Manner of Removal', 'Unsatisfactory Utilities - Electrical  Plumbing', 'Unsafe/Dangerous Conditions'
 ]

# %%
#create the violation severity column
def get_severity(desc):
    if desc in low:
        return "low"
    if desc in medium:
        return "medium"
    if desc in high:
        return "high"
    else:
        return 0
df_all["violation_severity"] = df_all.apply(lambda x: get_severity(x.description), axis = 1)

# %%
# drop columns with empty violation description 
df_all = df_all[df_all.violation_severity != 0]

# %%
print(df_all.shape)
df_all = df_all.drop_duplicates(subset=['description', 'address'])
print(df_all.shape)
# Out:
# (716873, 9)
# (302997, 9)

# %%
df_all.head()
# Out:
#            violation_type                  description  \
# 0  Enforcement Violations  Improper storage trash: res
# 1  Enforcement Violations  Improper storage trash: res
# 2  Enforcement Violations  Improper storage trash: res
# 3  Enforcement Violations  Improper storage trash: res
# 4  Enforcement Violations  Improper storage trash: res
#
#                      address                               owner  latitude  \
# 0      26-30 FLEET ST, 02113                    PIZZUTI DONATO F  42.36459
# 1  354-356 HANOVER ST, 02113              ORANGE TREE LANE TRUST  42.36521
# 2   16-18 HANOVER AVE, 02109  16-18  HANOVER AVENUE REALTY TRUST  42.36581
# 3    194 SALEM ST # 5, 02113                16 MYSTIC STREET LLC  42.36690
# 4      213 HANOVER ST, 02113                  CAPARELLA ROBERT A  42.36271
#
#    longitude       violation_date  year_built violation_severity
# 0  -71.05254  2022-10-27T00:00:00      1920.0                low
# ...

# %%
owners_with_violations = np.unique(df_all.owner)
len(owners_with_violations)
# Out:
# 76761

# %%
df_units_owned2 = df_all.groupby( ["owner"], as_index=False )["address"].nunique()


df_low = df_all.loc[df_all['violation_severity'] == 'low']
df_med = df_all.loc[df_all['violation_severity'] == 'medium']
df_high = df_all.loc[df_all['violation_severity'] == 'high']

len(df_low) + len(df_med) + len(df_high)

df_low_owners = df_low.groupby( [ "owner"], as_index=False )["violation_type"].count()
df_med_owners = df_med.groupby( [ "owner"], as_index=False )["violation_type"].count()
df_high_owners = df_high.groupby( [ "owner"], as_index=False )["violation_type"].count()

df_owner_info = pd.merge(df_low_owners, df_med_owners ,on ='owner', how = "outer")
df_owner_info = pd.merge(df_owner_info, df_high_owners ,on ='owner', how = "outer")
df_owner_info= df_owner_info.fillna(0)
df_owner_info = pd.merge(df_owner_info, df_units_owned2 ,on ='owner', how = "inner")


print(df_owner_info.shape)

df_owner_info = df_owner_info.rename(columns = {'violation_type_x' : 'num_low_violations', 'violation_type_y' : 'num_medium_violations', 'violation_type' : 'num_high_violations' , 'address': 'num_units_owned' } ) 
df_owner_info.head()
# Out:
# (76761, 5)
#                          owner  num_low_violations  num_medium_violations  \
# 0   36-38  CUNARD  STREET  LLC                 1.0                    0.0
# 1           CRISTALLO GINA  TS                 2.0                    3.0
# 2           GPD BRIMMER 4  LLC                 2.0                    0.0
# 3    GUIDO DOMINGOS DOS SANTOS                 1.0                    3.0
# 4           LOTUS  AVENUE  LLC                 2.0                    4.0
#
#    num_high_violations  num_units_owned
# 0                  0.0                1
# 1                  0.0                1
# 2                  0.0                1
# 3                  1.0                1
# 4                  1.0                1

# %%
df_all.to_csv("df_all.csv")
df_owner_info.to_csv("df_owner_info.csv")

# %%
#df_owner_info.loc[(df_owner_info["owner"]== 'GBM PORTFOLIO OWNER LLC')]
